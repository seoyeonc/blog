# %%
import pandas as pd

# %%
df1=pd.read_csv('mean_mse100.csv').iloc[:,1:]
df2=pd.read_csv('linear_mse100.csv').iloc[:,1:]

# %%
df1['node 2'].plot()
# Out:
# <AxesSubplot:>

# %%
df2['node 2'].plot()
# Out:
# <AxesSubplot:>
