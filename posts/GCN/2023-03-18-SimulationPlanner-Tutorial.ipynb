# %% [raw]
# ---
# title: "SimualtionPlanner-Tutorial"
# author: "SEOYEON CHOI"
# date: "2023-03-03"
# categories:
#   - ST-GCN
# ---

# %% [markdown]
# # imports

# %%
import itstgcn
import torch
import itstgcn.planner

# %% [markdown]
# # read data

# %%
_data = itstgcn.load_data('./data/fivenodes.pkl')
_edges = torch.tensor(_data['edges']).nonzero().tolist()
_FX = _data['f'].tolist()
_node_ids = {'node1':0, 'node2':1, 'node3':2, 'node4':3, 'node5':4} 
data_dict = {'edges':_edges, 'node_ids':_node_ids, 'FX':_FX}
loader = itstgcn.DatasetLoader(data_dict)

# %% [markdown]
# ## PLNR_STGCN_RAND

# %%
plans_stgcn_rand = {
    'max_iteration': 3, 
    'method': ['STGCN', 'IT-STGCN'], 
    'mrate': [0.0, 0.2, 0.4],
    'lags': [2, 4], 
    'nof_filters': [8,16], 
    'inter_method': ['nearest','linear'],
    'epoch': [1]
}

# %%
plnr = PLNR_STGCN_RAND(plans,loader,dataset_name='five_nodes')

# %%
plnr.simulate()
# Out:
# 1/3 is done
# 2/3 is done
# 3/3 is done

# %%
df = plnr.simulation_results
df
# Out:
#         dataset    method mrate mtype lags nof_filters inter_method epoch  \
# 0    five_nodes     STGCN   0.0  None    2           8         None     1
# 1    five_nodes     STGCN   0.0  None    2           8         None     1
# 2    five_nodes     STGCN   0.0  None    2          16         None     1
# 3    five_nodes     STGCN   0.0  None    2          16         None     1
# 4    five_nodes     STGCN   0.0  None    4           8         None     1
# ..          ...       ...   ...   ...  ...         ...          ...   ...
# 139  five_nodes  IT-STGCN   0.4  rand    2          16       linear     1
# 140  five_nodes  IT-STGCN   0.4  rand    4           8      nearest     1
# 141  five_nodes  IT-STGCN   0.4  rand    4           8       linear     1
# 142  five_nodes  IT-STGCN   0.4  rand    4          16      nearest     1
# 143  five_nodes  IT-STGCN   0.4  rand    4          16       linear     1
#
#           mse
# 0    1.202111
# 1    1.173311
# 2    1.170123
# 3     1.18629
# 4    1.238957
# ..        ...
# 139  1.195191
# 140  1.208371
# 141  1.160624
# 142   1.15774
# 143  1.217873
#
# [144 rows x 9 columns]

# %% [markdown]
# ## PLNR_STGCN_BLOCK

# %%
# _data = load_data('./data/fivenodes.pkl')

# _edges = torch.tensor(_data['edges']).nonzero().tolist()
# _FX = _data['f'].tolist()
# _node_ids = {'node1':0, 'node2':1, 'node3':2, 'node4':3, 'node5':4} 

data_dict = {'edges':_edges, 'node_ids':_node_ids, 'FX':_FX}

# %%
loader = DatasetLoader(data_dict)

# %%
mindex_block = [list(range(10,100)),[],list(range(50,80)),[],[]]
plans_stgcn_block = {
    'max_iteration': 3, 
    'method': ['STGCN', 'IT-STGCN'], 
    'mindex': [mindex_block],
    'lags': [2, 4], 
    'nof_filters': [8,16], 
    'inter_method': ['nearest','linear'],
    'epoch': [1]
}

# %%
plnr = PLNR_STGCN_BLOCK(plans_stgcn_block,loader,dataset_name='five_nodes')

# %%
plnr.simulate()
# Out:
# 1/1

# %%
df = plnr.simulation_results
df
# Out:
#        dataset    method mrate  mtype lags nof_filters inter_method epoch  \
# 0   five_nodes     STGCN   0.5  block    2           8      nearest     1
# 1   five_nodes     STGCN   0.5  block    2           8       linear     1
# 2   five_nodes     STGCN   0.5  block    2          16      nearest     1
# 3   five_nodes     STGCN   0.5  block    2          16       linear     1
# 4   five_nodes     STGCN   0.5  block    4           8      nearest     1
# 5   five_nodes     STGCN   0.5  block    4           8       linear     1
# 6   five_nodes     STGCN   0.5  block    4          16      nearest     1
# 7   five_nodes     STGCN   0.5  block    4          16       linear     1
# 8   five_nodes  IT-STGCN   0.5  block    2           8      nearest     1
# 9   five_nodes  IT-STGCN   0.5  block    2           8       linear     1
# 10  five_nodes  IT-STGCN   0.5  block    2          16      nearest     1
# 11  five_nodes  IT-STGCN   0.5  block    2          16       linear     1
# 12  five_nodes  IT-STGCN   0.5  block    4           8      nearest     1
# 13  five_nodes  IT-STGCN   0.5  block    4           8       linear     1
# 14  five_nodes  IT-STGCN   0.5  block    4          16      nearest     1
# 15  five_nodes  IT-STGCN   0.5  block    4          16       linear     1
# 16  five_nodes     STGCN   0.5  block    2           8      nearest     1
# 17  five_nodes     STGCN   0.5  block    2           8       linear     1
# 18  five_nodes     STGCN   0.5  block    2          16      nearest     1
# 19  five_nodes     STGCN   0.5  block    2          16       linear     1
# 20  five_nodes     STGCN   0.5  block    4           8      nearest     1
# 21  five_nodes     STGCN   0.5  block    4           8       linear     1
# 22  five_nodes     STGCN   0.5  block    4          16      nearest     1
# 23  five_nodes     STGCN   0.5  block    4          16       linear     1
# 24  five_nodes  IT-STGCN   0.5  block    2           8      nearest     1
# 25  five_nodes  IT-STGCN   0.5  block    2           8       linear     1
# 26  five_nodes  IT-STGCN   0.5  block    2          16      nearest     1
# 27  five_nodes  IT-STGCN   0.5  block    2          16       linear     1
# 28  five_nodes  IT-STGCN   0.5  block    4           8      nearest     1
# 29  five_nodes  IT-STGCN   0.5  block    4           8       linear     1
# 30  five_nodes  IT-STGCN   0.5  block    4          16      nearest     1
# 31  five_nodes  IT-STGCN   0.5  block    4          16       linear     1
# 32  five_nodes     STGCN   0.5  block    2           8      nearest     1
# 33  five_nodes     STGCN   0.5  block    2           8       linear     1
# 34  five_nodes     STGCN   0.5  block    2          16      nearest     1
# 35  five_nodes     STGCN   0.5  block    2          16       linear     1
# 36  five_nodes     STGCN   0.5  block    4           8      nearest     1
# 37  five_nodes     STGCN   0.5  block    4           8       linear     1
# 38  five_nodes     STGCN   0.5  block    4          16      nearest     1
# 39  five_nodes     STGCN   0.5  block    4          16       linear     1
# 40  five_nodes  IT-STGCN   0.5  block    2           8      nearest     1
# 41  five_nodes  IT-STGCN   0.5  block    2           8       linear     1
# 42  five_nodes  IT-STGCN   0.5  block    2          16      nearest     1
# 43  five_nodes  IT-STGCN   0.5  block    2          16       linear     1
# 44  five_nodes  IT-STGCN   0.5  block    4           8      nearest     1
# 45  five_nodes  IT-STGCN   0.5  block    4           8       linear     1
# 46  five_nodes  IT-STGCN   0.5  block    4          16      nearest     1
# 47  five_nodes  IT-STGCN   0.5  block    4          16       linear     1
#
#          mse
# 0   1.162601
# 1   1.145895
# 2   1.166197
# 3   1.165355
# 4   1.157954
# 5   1.162674
# 6   1.179143
# 7   1.175561
# 8   1.195364
# 9     1.2184
# 10  1.210481
# 11  1.169326
# 12  1.193523
# 13  1.199567
# 14  1.201094
# 15  1.210867
# 16  1.169622
# 17  1.173848
# 18  1.176841
# 19   1.15848
# 20  1.191304
# 21  1.155874
# 22  1.188419
# 23  1.197183
# 24  1.210021
# 25  1.184674
# 26  1.274009
# 27  1.188723
# 28  1.217735
# 29  1.202317
# 30  1.219543
# 31  1.202418
# 32  1.158991
# 33  1.187762
# 34  1.182213
# 35  1.161439
# 36  1.188787
# 37  1.233327
# 38   1.15206
# 39  1.161346
# 40  1.215097
# 41  1.163064
# 42  1.206054
# 43  1.177454
# 44  1.233471
# 45  1.209842
# 46  1.221017
# 47  1.218403

# %% [markdown]
# ## PLNR_GNAR_RAND

# %%
# _data = load_data('./data/fivenodes.pkl')

# _edges = torch.tensor(_data['edges']).nonzero().tolist()
# _FX = _data['f'].tolist()
# _node_ids = {'node1':0, 'node2':1, 'node3':2, 'node4':3, 'node5':4} 

data_dict = {'edges':_edges, 'node_ids':_node_ids, 'FX':_FX}

# %%
loader = DatasetLoader(data_dict)

# %%
plans_gnar_rand = {
    'max_iteration': 3, 
#    'method': ['GNAR'], 
    'mrate': [0.0, 0.2, 0.4],
    'lags': [2, 4], 
#    'nof_filters': [8,16], 
    'inter_method': ['nearest','linear'],
#    'epoch': [1]
}

# %%
plnr = PLNR_GNAR_RAND(plans_gnar_rand,loader,dataset_name='five_nodes')
plnr.simulate()
# Out:
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed

# %%
plnr.simulation_results
# Out:
#        dataset method mrate mtype lags nof_filters inter_method epoch  \
# 0   five_nodes   GNAR   0.0  None    2        None         None  None
# 1   five_nodes   GNAR   0.0  None    2        None         None  None
# 2   five_nodes   GNAR   0.0  None    4        None         None  None
# 3   five_nodes   GNAR   0.0  None    4        None         None  None
# 4   five_nodes   GNAR   0.2  rand    2        None      nearest  None
# 5   five_nodes   GNAR   0.2  rand    2        None       linear  None
# 6   five_nodes   GNAR   0.2  rand    4        None      nearest  None
# 7   five_nodes   GNAR   0.2  rand    4        None       linear  None
# 8   five_nodes   GNAR   0.4  rand    2        None      nearest  None
# 9   five_nodes   GNAR   0.4  rand    2        None       linear  None
# 10  five_nodes   GNAR   0.4  rand    4        None      nearest  None
# 11  five_nodes   GNAR   0.4  rand    4        None       linear  None
# 12  five_nodes   GNAR   0.0  None    2        None         None  None
# 13  five_nodes   GNAR   0.0  None    2        None         None  None
# 14  five_nodes   GNAR   0.0  None    4        None         None  None
# 15  five_nodes   GNAR   0.0  None    4        None         None  None
# 16  five_nodes   GNAR   0.2  rand    2        None      nearest  None
# 17  five_nodes   GNAR   0.2  rand    2        None       linear  None
# 18  five_nodes   GNAR   0.2  rand    4        None      nearest  None
# 19  five_nodes   GNAR   0.2  rand    4        None       linear  None
# 20  five_nodes   GNAR   0.4  rand    2        None      nearest  None
# 21  five_nodes   GNAR   0.4  rand    2        None       linear  None
# 22  five_nodes   GNAR   0.4  rand    4        None      nearest  None
# 23  five_nodes   GNAR   0.4  rand    4        None       linear  None
# 24  five_nodes   GNAR   0.0  None    2        None         None  None
# 25  five_nodes   GNAR   0.0  None    2        None         None  None
# 26  five_nodes   GNAR   0.0  None    4        None         None  None
# 27  five_nodes   GNAR   0.0  None    4        None         None  None
# 28  five_nodes   GNAR   0.2  rand    2        None      nearest  None
# 29  five_nodes   GNAR   0.2  rand    2        None       linear  None
# 30  five_nodes   GNAR   0.2  rand    4        None      nearest  None
# 31  five_nodes   GNAR   0.2  rand    4        None       linear  None
# 32  five_nodes   GNAR   0.4  rand    2        None      nearest  None
# 33  five_nodes   GNAR   0.4  rand    2        None       linear  None
# 34  five_nodes   GNAR   0.4  rand    4        None      nearest  None
# 35  five_nodes   GNAR   0.4  rand    4        None       linear  None
#
#          mse
# 0    1.40683
# 1    1.40683
# 2   1.469004
# 3   1.469004
# 4    1.40683
# 5    1.40683
# 6   1.469004
# 7   1.469004
# 8    1.40683
# 9    1.40683
# 10  1.469004
# 11  1.469004
# 12   1.40683
# 13   1.40683
# 14  1.469004
# 15  1.469004
# 16   1.40683
# 17   1.40683
# 18  1.469004
# 19  1.469004
# 20   1.40683
# 21   1.40683
# 22  1.469004
# 23  1.469004
# 24   1.40683
# 25   1.40683
# 26  1.469004
# 27  1.469004
# 28   1.40683
# 29   1.40683
# 30  1.469004
# 31  1.469004
# 32   1.40683
# 33   1.40683
# 34  1.469004
# 35  1.469004

# %% [markdown]
# ## PLNR_GNAR_BLOCK

# %%
# _data = load_data('./data/fivenodes.pkl')

# _edges = torch.tensor(_data['edges']).nonzero().tolist()
# _FX = _data['f'].tolist()
# _node_ids = {'node1':0, 'node2':1, 'node3':2, 'node4':3, 'node5':4} 

data_dict = {'edges':_edges, 'node_ids':_node_ids, 'FX':_FX}

# %%
loader = DatasetLoader(data_dict)

# %%
mindex_block = [list(range(10,100)),[],list(range(50,80)),[],[]]
plans_gnar_block = {
    'max_iteration': 3, 
    'method': ['GNAR'], 
    'mindex': [mindex_block],
    'lags': [2, 4], 
    'inter_method': ['nearest','linear'],
}

# %%
plnr = PLNR_GNAR_BLOCK(plans_gnar_block,loader,dataset_name='five_nodes')
plnr.simulate()
# Out:
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed
# WARNING: diagonal entries present in original matrix, these will be removed

# %%
plnr.simulation_results
# Out:
#        dataset method mrate  mtype lags nof_filters inter_method epoch  \
# 0   five_nodes   GNAR   0.5  block    2        None      nearest  None
# 1   five_nodes   GNAR   0.5  block    2        None       linear  None
# 2   five_nodes   GNAR   0.5  block    4        None      nearest  None
# 3   five_nodes   GNAR   0.5  block    4        None       linear  None
# 4   five_nodes   GNAR   0.5  block    2        None      nearest  None
# 5   five_nodes   GNAR   0.5  block    2        None       linear  None
# 6   five_nodes   GNAR   0.5  block    4        None      nearest  None
# 7   five_nodes   GNAR   0.5  block    4        None       linear  None
# 8   five_nodes   GNAR   0.5  block    2        None      nearest  None
# 9   five_nodes   GNAR   0.5  block    2        None       linear  None
# 10  five_nodes   GNAR   0.5  block    4        None      nearest  None
# 11  five_nodes   GNAR   0.5  block    4        None       linear  None
#
#          mse
# 0    1.40683
# 1    1.40683
# 2   1.469004
# 3   1.469004
# 4    1.40683
# 5    1.40683
# 6   1.469004
# 7   1.469004
# 8    1.40683
# 9    1.40683
# 10  1.469004
# 11  1.469004
