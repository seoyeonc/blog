# %% [markdown]
# # ITSTGCN Article Refernece
#
# SEOYEON CHOI
# 2023-05-06
#
# > summerizing it
#
# > **Note**
# >
# > -   글이 진행되는 순서로 작성함.
#
# # Introduction
#
# `little1989analysis`
#
# -   The analysis of social science data with missing values
#     -   Little, Roderick JA and Rubin, Donald B
#
# 위 논문은 구하지 못했고, 아래 논문에서 refer 건 것 보고 작성
#
# Evaluating the Influence of Missing Data on Classification Algorithms in
# Data Mining Applications by Luciano C. Blomberg
#
# 내용
#
# -   Furthermore, distribution of missing data is another aspect that may
#     influence the effectiveness of classification algorithms. Litle and
#     Rubin \[1987\] presented three different mechanisms by which the
#     missing data are distributed:
#
# `li2018missing`
#
# -   Missing value imputation for traffic-related time series data based
#     on a multi-view learning method
#     -   Li, Linchao and Zhang, Jian and Wang, Yonggang and Ran, Bin
#
# 내용
#
# -   In this circumstance, the difficulty of imputation is increased as
#     we may not be able to find stable inputs for a model.
#
# **Spatiotemporal Data**
#
# `atluri2018spatio`
#
# -   Spatio-temporal data mining: A survey of problems and methods
#     -   Atluri, Gowtham and Karpatne, Anuj and Kumar, Vipin
#
# 내용
#
# -   3.2. Data type 내용
#
# `wang2020deep`
#
# -   Deep learning for spatio-temporal data mining: A survey
#     -   Wang, Senzhang and Cao, Jiannong and Yu, Philip
#
# 내용
#
# -   2.1. Spatio-Temporal Data Types 항목 내용에서 STData 종류
#
# `yu2017spatio`
#
# -   Spatio-temporal graph convolutional networks: A deep learning
#     framework for traffic forecasting
#     -   Yu, Bing and Yin, Haoteng and Zhu, Zhanxing
#
# 내용
#
# -   The linear interpolation method is used to fill missing values after
#     data cleaning.
#
# `guo2019attention`
#
# -   Attention based spatial-temporal graph convolutional networks for
#     traffic flow forecasting
#     -   Guo, Shengnan and Lin, Youfang and Feng, Ning and Song, Chao and
#         Wan, Huaiyu
#
# 내용
#
# -   The missing values are filled by the linear interpolation.
#
# `bai2020adaptive`
#
# -   Adaptive graph convolutional recurrent network for traffic
#     forecasting
#     -   Bai, Lei and Yao, Lina and Li, Can and Wang, Xianzhi and Wang,
#         Can
#
# 내용
#
# -   The missing values in the datasets are filled by linear
#     interpolation.
#
# `li2019predicting`
#
# -   Predicting path failure in time-evolving graphs
#     -   Li, Jia and Han, Zhichao and Cheng, Hong and Su, Jiao and Wang,
#         Pengyun and Zhang, Jianfeng and Pan, Lujia
#
# 내용
#
# -   We replace missing values with 0, and normalize the features to the
#     range
#
# `zhao2019t`
#
# -   T-GCN: A Temporal Graph Convol- utional Network for Traffic
#     Prediction
#     -   Zhao, Ling and Song, Yujiao and Zhang, Chao and Liu, Yu and
#         Wang, Pu and Lin, Tao and Deng, Min and Li, Haifeng
#
# 내용
#
# -   we used the linear interpolation method to fill missing values.
#
# `baraldi2010introduction`
#
# -   An introduction to modern missing data analyses
#     -   Baraldi, Amanda N and Enders, Craig K
#
# 내용
#
# -   An overview of traditional missing data techniques 항목
#
# `shi2022air`
#
# -   Air Quality Prediction Model Based on Spatio-temporal Graph
#     Convolution Neural Networks
#     -   Shi, Weidi and Song, Anjun
#
# 내용
#
# -   Due to weather reasons and corrosion or damage of some sensors, some
#     data were lost and abnormal. Therefore, the data needs to be
#     cleaned. We used the average imputation method to fill some lost
#     data and deleted the data which lost too many values.
#
# `batista2003analysis`
#
# -   An analysis of four missing data treatment methods for supervised
#     learning
#     -   Batista, Gustavo EAPA and Monard, Maria Carolina
#
# 내용
#
# -   IMPUTATION METHODS
# -   Imputation methods involve replacing missing values with estimated
#     ones based on information available in the data set. There are many
#     options varying from naive methods, such as mean imputation, to some
#     more robust methods based on relationships among attributes. A
#     description of some widely used imputation methods follows:
#
# `blomberg2013evaluating`
#
# -   Evaluating the performance of regression algorithms on datasets with
#     missing data
#     -   Blomberg, Luciano Costa and Hemerich, Daiane and Ruiz, Duncan
#         Dubugras Alcoba
#
# 내용
#
# -   for example, replaces the missing values with means or modes.
#
# `donders2006gentle`
#
# -   Review: A gentle introduction to imputation of missing values
#     -   Donders, A Rogier T and Van Der Heijden, Geert JMG and Stijnen,
#         Theo and Moons, Karel GM
#
# 내용
#
# -   the indicator method and overall mean imputation, give biased
#     results.
# -   The mean of the standard errors is a measure for the uncertainty in
#     the estimated associations caused by sampling the study subjects
#     from a source popu- lation. Additionally, the standard deviation of
#     the multiple estimated associations (e.g., regression coefficients)
#     reflects the differences between the imputed data sets, i.e., the
#     un- certainty in the estimated underlying distributions of the
#     variables with missing values.
#
# `baraldi2010introduction`
#
# -   An introduction to modern missing data analyses
#     -   Baraldi, Amanda N and Enders, Craig K
#
# 내용
#
# -   To illustrate the bias that can result from the use of traditional
#     missing data methods, we use the artificial math performance data
#     set found in Table 1.
#
# # Proposed Methods
#
# **Self-Consistent Estimator**
